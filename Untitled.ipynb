# %%
import astroquery
from astropy.io import fits

import numpy as np
import matplotlib.pyplot as plt
import sep

# %%
im, hdr = fits.getdata('/Users/tinglu/iCloudLink/iCloud Teaching/future/2019 Fall/Observational Astro/sample data/UITfuv2582gc.fits', header=True)

im = im*1e13

fig = plt.figure()

# %%
plt.imshow(im, vmin = -0.05, vmax = 0.05)
